# %% [markdown]
# # Make files with binary outputs simulations

# %% [markdown]
# Here there's a funtion to save the outputs in a file we can use for plotting without extracting all the time the data, the funtion only depends on the directory path where the results are.

# %%
import os
import re
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

from my_funcs import *
# Out:
# <function my_funcs.extract_custar_from_dir(work_dir)>

# %% [markdown]
# #### Create a general function that only need the path

# %%
# common for all cases
L0 = 2.0 * np.pi
h = 1
u_s = 0.25
N = 512
k_ = 4
rho_r = 1000 / 1.225
Re_tau = 720
rho1 = 1
rho2 = rho1 / rho_r
mu2 = rho2 * u_s * (L0 - h) / Re_tau
tot_row = 18;

# %%
work_dir = "/projects/DEIKE/cmartinb/ak0.2_Bo200_custar2/forward/"
process_directory(work_dir, L0, N, tot_row, k_, mu2)
# Out:
# ****************
# 30837 38.5001 0
# ****************
# 75956
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30909 38.59827477 1
# ****************
# 289820
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30973 38.696449541 2
# ****************
# 287054
# First pass of remove
# Second pass of remove
# ...

# %%
work_dir = "/projects/DEIKE/cmartinb/ak0.2_Bo200_custar2/backward/"
process_directory(work_dir, L0, N, tot_row, k_, mu2)
# Out:
# ****************
# 30837 38.5001 0
# ****************
# 75956
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30909 38.59827477 1
# ****************
# 286781
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30973 38.696449541 2
# ****************
# 287890
# First pass of remove
# Second pass of remove
# ...

# %%
work_dir = "/projects/DEIKE/cmartinb/ak0.2_Bo200_custar4/forward/"
process_directory(work_dir, L0, N, tot_row, k_, mu2)

# %%
work_dir = "/projects/DEIKE/cmartinb/ak0.2_Bo200_custar4/backward/"
process_directory(work_dir, L0, N, tot_row, k_, mu2)
# Out:
# ****************
# 30837 38.5001 0
# ****************
# 75956
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30879 38.549187385 1
# ****************
# 289845
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30911 38.59827477 2
# ****************
# 288344
# First pass of remove
# Second pass of remove
# ...

# %%
work_dir = "/projects/DEIKE/cmartinb/ak0.2_Bo200_custar8/forward/"
process_directory(work_dir, L0, N, tot_row, k_, mu2)
# Out:
# ****************
# 30837 38.5001 0
# ****************
# 75956
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30865 38.524643693 1
# ****************
# 290497
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30881 38.549187385 2
# ****************
# 290032
# First pass of remove
# Second pass of remove
# ...

# %%
work_dir = "/projects/DEIKE/cmartinb/ak0.2_Bo200_custar8/backward/"
process_directory(work_dir, L0, N, tot_row, k_, mu2)
# Out:
# ****************
# 30837 38.5001 0
# ****************
# 75956
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30866 38.524643693 1
# ****************
# 288864
# First pass of remove
# Second pass of remove
# Assign array
# Interpolation to a Cartesian grid
# Compute momentum flux - pressure
# Compute momentum flux - viscous dissipation
# Energy flux - pressure
# Energy flux - viscous dissipation
# Load field and phase partition
# From cartesian to wf
# Final print of glo_obs
# Final print of glo_obs alt
# Final print of wf
# ****************
# 30883 38.549187385 2
# ****************
# 288387
# First pass of remove
# Second pass of remove
# ...
